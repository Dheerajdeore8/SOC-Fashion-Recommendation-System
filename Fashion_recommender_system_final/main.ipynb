# %%
import tensorflow
from tensorflow.keras.preprocessing import image
from tensorflow.keras.layers import GlobalMaxPooling2D
from tensorflow.keras.applications.resnet50 import ResNet50,preprocess_input
import numpy as np
from numpy.linalg import norm
import os
from tqdm import tqdm
import pickle

model = ResNet50(weights='imagenet',include_top=False,input_shape=(224,224,3))
model.trainable = False

model = tensorflow.keras.Sequential([
    model,
    GlobalMaxPooling2D()
])

#print(model.summary())

def extract_features(img_path,model):
    img = image.load_img(img_path,target_size=(224,224))
    img_array = image.img_to_array(img)
    expanded_img_array = np.expand_dims(img_array, axis=0)
    preprocessed_img = preprocess_input(expanded_img_array)
    result = model.predict(preprocessed_img).flatten()
    normalized_result = result / norm(result)

    return normalized_result

filenames = []

for file in os.listdir("/content/drive/MyDrive/SOC '24 mentee/images"):
    filenames.append(os.path.join("/content/drive/MyDrive/SOC '24 mentee/images",file))

feature_list = []

for file in tqdm(filenames):
    feature_list.append(extract_features(file,model))

pickle.dump(feature_list,open('embeddings.pkl','wb'))
pickle.dump(filenames,open('filenames.pkl','wb'))
# Out:
#   0%|          | 0/1546 [00:00<?, ?it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
#   0%|          | 1/1546 [00:03<1:31:22,  3.55s/it]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 367ms/step
#   0%|          | 2/1546 [00:04<57:53,  2.25s/it]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 375ms/step
#   0%|          | 3/1546 [00:06<46:59,  1.83s/it]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 228ms/step
#   0%|          | 4/1546 [00:07<36:37,  1.43s/it]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 235ms/step
#   0%|          | 5/1546 [00:07<31:57,  1.24s/it]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 258ms/step
#   0%|          | 6/1546 [00:08<29:28,  1.15s/it]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 217ms/step
#   0%|          | 7/1546 [00:09<26:47,  1.04s/it]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 217ms/step
#   1%|          | 8/1546 [00:10<26:18,  1.03s/it]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 224ms/step
#   1%|          | 9/1546 [00:11<25:54,  1.01s/it]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 201ms/step
#   1%|          | 10/1546 [00:12<24:31,  1.04it/s]
# ...

# %%
pickle.dump(feature_list,open("/content/drive/MyDrive/SOC '24 mentee/embeddings.pkl",'wb'))
pickle.dump(filenames,open("/content/drive/MyDrive/SOC '24 mentee/filenames.pkl",'wb'))

# %%
filenames[0]
# Out:
# "/content/drive/MyDrive/SOC '24 mentee/images/10076.jpg"

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive
